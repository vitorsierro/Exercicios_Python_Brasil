# %% [markdown]
# Crie um algoritmo em Python que peça uma nota, entre zero e 100. Mostre uma mensagem caso o valor seja inválido e continue pedindo até que o usuário informe um valor válido.

# %%
def inserir():
    try:
        numero =  float(input("Digite um valor valido "))
    except:
        numero = inserir() 
    return numero
valor = []
while  len(valor) < 100 :
    valor.append(inserir())
valor

# %% [markdown]
# Crie um algoritmo em Python que leia um nome de usuário e a sua senha e não aceite a senha igual ao nome do usuário, mostrando uma mensagem de erro e voltando a pedir as informações.<br>

# %%
import getpass
while True:
        login =  input("Digite um login valido ")
        senha = getpass.getpass(prompt='Digite sua Senha: ', stream=None)
        if (login == senha or login.upper == senha.upper):
            print("você digitou uma senha igual ao login")
            continue
        else:
          print("Login efetuado com sucesso")
          break
# Out:
# Digite um login valido vitor
# Digite sua Senha: ··········
# você digitou uma senha igual ao login
# Digite um login valido vitor
# Digite sua Senha: ··········
# Login efetuado com sucesso

# %% [markdown]
# Crie um algoritmo em Python que leia e valide as seguintes informações:
# * Nome: maior que 3 caracteres;
# * Idade: entre 0 e 150;
# * Salário: maior que zero;
# * Sexo: 'f' ou 'm';
# * Estado Civil: 's', 'c', 'v', 'd';

# %%
while True:
    nome = str(input("Digite um nome ")).upper()
    if len(nome) > 3:
        idade = int(input("Digite uma idade "))
        if 150 > idade > 0:
            salario = float(input("Digite seu salario "))
            if salario >= 0:
                sexo = str(input("Digite seu sexo M-masculino e F-feminino ")).upper()
                if sexo == "M":
                    sexo = "Masculino"
                    estado_civil = str(input("Digite seu estado civil S-Solteiro C-Casado V-Viuvo D-Divorciado ")).upper()
                    if estado_civil == "S":
                        estado_civil = "Solteiro"
                    elif estado_civil == "C":
                        estado_civil = "Casado"
                    elif estado_civil == "V":
                        estado_civil = "Viuvo"
                    else:
                        estado_civil = "Divorciado"
                    print("Seus dados estão validos")
                    print("Seu nome é {0} sua idade {1} seu salario atual é {2} você pertence ao sexo {3} e está {4}".format(nome,idade,salario,sexo,estado_civil))                    
                    break
                elif sexo == "F":
                    sexo = "Feminino"
                    estado_civil = str(input("Digite seu estado civil S-Solteiro C-Casado V-Viuvo D-Divorciado ")).upper()
                    if estado_civil == "S":
                        estado_civil = "Solteira"
                    elif estado_civil == "C":
                        estado_civil = "Casada"
                    elif estado_civil == "V":
                        estado_civil = "Viuva"
                    else:
                        estado_civil = "Divorciada"
                    print("Seus dados estão validos")
                    print("Seu nome é {0} sua idade {1} seu salario atual é {2} você pertence ao sexo {3} e está {4}".format(nome,idade,salario,sexo,estado_civil))                    
                    break
                else:
                    continue
    else:
        continue
# Out:
# Digite um nome vi
# Digite um nome vitor
# Digite uma idade 200
# Digite um nome vitor
# Digite uma idade 100
# Digite seu salario -20
# Digite um nome vitor
# Digite uma idade 100
# Digite seu salario 1000
# Digite seu sexo M-masculino e F-feminino feminino
# Digite um nome vitor
# Digite uma idade 100
# Digite seu salario 1000
# Digite seu sexo M-masculino e F-feminino m
# Digite seu estado civil S-Solteiro C-Casado V-Viuvo D-Divorciado Divorciado
# Seus dados estão validos
# Seu nome é VITOR sua idade 100 seu salario atual é 1000.0 você pertence ao sexo Masculino e está Divorciado

# %% [markdown]
# Supondo que a população de um país A seja da ordem de 80000 habitantes com uma taxa anual de crescimento de 3% e que a população de B seja 200000 habitantes com uma taxa de crescimento de 1.5%.<br><br> Crie um algoritmo em Python que calcule e escreva o número de anos necessários para que a população do país A ultrapasse ou iguale a população do país B, mantidas as taxas de crescimento.

# %%
pop_a = 80000
pop_b = 200000
teste = 0
anos = 0
while teste == 0:
    pop_a +=  (pop_a * (3/100))
    pop_b +=  (pop_b * (1.5/100))
    anos += 1
    if pop_a > pop_b:
       teste = 1
       break
print("A população A tem {0} e a população B tem {1}".format(int(pop_a),int(pop_b)))
print("Em {0} anos".format(anos))
# Out:
# A população A tem 515033 e a população B tem 510964
# Em 63

# %% [markdown]
# Desenvolva um gerador de tabuada, capaz de gerar a tabuada de qualquer número inteiro entre 1 a 10. O usuário deve informar de qual numero ele deseja ver a tabuada. A saída deve ser conforme o exemplo abaixo:
# Tabuada de 5:<br>
# 5 X 1 = 5<br>
# 5 X 2 = 10<br>
# ...<br>
# 5 X 10 = 50<br>

# %%
num = int(input("Digite qual a tabuada você deseja "))
num2 = int(input("Digite até que valor você deseja que a tabuada vá "))
print("A tabuada do {0} é".format(num))
for i in range(num2 + 1 ):
    print("{0} X {1} = {2}".format(num,i, num*i))
# Out:
# Digite qual a tabuada você deseja 10
# Digite até que valor você deseja que a tabuada vá 20
# A tabuada do 10 é
# 10 X 0 = 0
# 10 X 1 = 10
# 10 X 2 = 20
# 10 X 3 = 30
# 10 X 4 = 40
# 10 X 5 = 50
# 10 X 6 = 60
# 10 X 7 = 70
# 10 X 8 = 80
# 10 X 9 = 90
# 10 X 10 = 100
# 10 X 11 = 110
# 10 X 12 = 120
# 10 X 13 = 130
# 10 X 14 = 140
# 10 X 15 = 150
# 10 X 16 = 160
# 10 X 17 = 170
# 10 X 18 = 180
# 10 X 19 = 190
# 10 X 20 = 200

# %% [markdown]
# Crie um algoritmo em Python que leia três números e mostre o maior e o menor deles.

# %%
var1 = input("Digite um numero ")
var2 = input("Digite qualquer valor ")
var3 = input("Digite qualquer valor ")
if (var1 < var2) and (var1 < var3):
  print("O valor {0} é o maior numero".format(var1))
elif var2 < var3:
  print("O valor {0} é o maior numero".format(var2))
else:
  print("O valor {0} é o maior numero".format(var3))

# %% [markdown]
# Crie um algoritmo em Python que peça 2 números, base e expoente, calcule e mostre o primeiro número elevado ao segundo número. Não utilize a função de potência da linguagem.

# %%
calc = 1
num = int(input("Digite qual a sua base "))
num2 = int(input("Digite seu expoente "))
for i in range(num2):
    calc *= num 
print("{0} ** {1} = {2}".format(num,num2,calc))
# Out:
# Digite qual a sua base 2
# Digite seu expoente 10
# 2 ** 10 = 1024

# %% [markdown]
# Crie um algoritmo em Python que peça 10 números inteiros, calcule e mostre a quantidade de números pares e a quantidade de números impares.

# %%
num = []
i = par = impar = 0
while len(num) < 10:
    num.append(int(input("Digite um numero inteiro ")))
    if num[i] % 2:
        par += 1
    else:
        impar += 1
    i += 1
print("A quantidade de números pares é {0} e de numero impar é {1}".format(par,impar))
# Out:
# Digite um numero inteiro 2
# Digite um numero inteiro 3
# Digite um numero inteiro 4
# Digite um numero inteiro 5
# Digite um numero inteiro 6
# Digite um numero inteiro 7
# Digite um numero inteiro 8
# Digite um numero inteiro 9
# Digite um numero inteiro 10
# Digite um numero inteiro 12
# A quantidade de números pares é 4 e de numero impar é 6

# %% [markdown]
# Um funcionário de uma empresa recebe aumento salarial anualmente: Sabe-se que:
# Esse funcionário foi contratado em 1995, com salário inicial de R$ 1.000,00;
# Em 1996 recebeu aumento de 1,5% sobre seu salário inicial;
# A partir de 1997 (inclusive), os aumentos salariais sempre correspondem ao dobro do percentual do ano anterior. Crie um algoritmo em Python que determine o salário atual desse funcionário. Após concluir isto, altere o programa permitindo que o usuário digite o salário inicial do funcionário.

# %%
sal = 1000
saL_um_ano = sal * 1.5
ano = 1996
porc = 1.5
while ano != 2020:
    porc = porc * 2
    sal_novo = saL_um_ano * porc
    ano += 1
    print("{0} {1} {2}".format(porc, sal_novo, ano))
print("O salario desse funcionario em 2020 é {0}".format(sal_novo))
# Out:
# 3.0 4500.0 1997
# 6.0 9000.0 1998
# 12.0 18000.0 1999
# 24.0 36000.0 2000
# 48.0 72000.0 2001
# 96.0 144000.0 2002
# 192.0 288000.0 2003
# 384.0 576000.0 2004
# 768.0 1152000.0 2005
# 1536.0 2304000.0 2006
# 3072.0 4608000.0 2007
# 6144.0 9216000.0 2008
# 12288.0 18432000.0 2009
# 24576.0 36864000.0 2010
# 49152.0 73728000.0 2011
# 98304.0 147456000.0 2012
# 196608.0 294912000.0 2013
# 393216.0 589824000.0 2014
# 786432.0 1179648000.0 2015
# 1572864.0 2359296000.0 2016
# 3145728.0 4718592000.0 2017
# 6291456.0 9437184000.0 2018
# 12582912.0 18874368000.0 2019
# 25165824.0 37748736000.0 2020
# O salario desse funcionario em 2020 é 37748736000.0

# %% [markdown]
# Crie um algoritmo em Python com uma função que necessite de um argumento. A função retorna o valor de caractere ‘P’, se seu argumento for positivo, e ‘N’, se seu argumento for zero ou negativo.

# %%
def posiNega (num):
    if num > 0:
        print("Positivo")
    else:
        print("Negativo")
posiNega(10)
# Out:
# Positivo

# %% [markdown]
# Construa uma função que receba uma data no formato DD/MM/AAAA e devolva uma string no formato D de mesPorExtenso de AAAA. Opcionalmente, valide a data e retorne NULL caso a data seja inválida.

# %%
def calendario(data):
    # faz o split e transforma em números
    dia, mes, ano = map(int, data.split('/'))

    # mês ou ano inválido (só considera do ano 1 em diante), retorna False
    if mes < 1 or mes > 12 or ano <= 0:
        return False

    # verifica qual o último dia do mês
    if mes in (1, 3, 5, 7, 8, 10, 12):
        ultimo_dia = 31
    elif mes == 2:
        # verifica se é ano bissexto
        if (ano % 4 == 0) and (ano % 100 != 0 or ano % 400 == 0):
            ultimo_dia = 29
        else:
            ultimo_dia = 28
    else:
        ultimo_dia = 30

    # verifica se o dia é válido
    if dia < 1 or dia > ultimo_dia:
        return False
        
    return print("Data Valida")

data = input("Digite sua data")
calendario(data)

# %% [markdown]
# Crie uma classe que modele uma pessoa:<br>
#
# Atributos: nome, idade, peso e altura<br>
# Métodos: Envelhercer, engordar, emagrecer, crescer.<br>
# <br>Obs: Por padrão, a cada ano que nossa pessoa envelhece, sendo a idade dela menor que 21 anos, ela deve crescer 0,5 cm.

# %%
idade = peso = altura = 0
def envelhercer (idade, altura):
    idade +=  1
    if idade < 21:
        altura += 5
        print("teste")
        return (idade, altura)
    return idade 

def engordar (peso):
    peso += 1
    return peso

def emagrecer (peso):
    peso -= 1
    return peso 

def crescer(altura):
    altura += 5
    return altura

idade = 18
altura = 170
peso = 60
peso2 = 70
for i in range (20):
    peso = engordar(peso)
    print("Peso:{0}".format(peso))
    peso2 = emagrecer(peso2)
    print("Peso:{0}".format(peso2))
    altura = crescer(altura)
    print("Altura:{0}".format(altura))
    print("")
# Out:
# Peso:61
# Peso:69
# Altura:175
#
# Peso:62
# Peso:68
# Altura:180
#
# Peso:63
# Peso:67
# Altura:185
#
# Peso:64
# Peso:66
# Altura:190
#
# Peso:65
# Peso:65
# Altura:195
#
# Peso:66
# Peso:64
# Altura:200
#
# Peso:67
# Peso:63
# Altura:205
#
# Peso:68
# Peso:62
# Altura:210
#
# Peso:69
# Peso:61
# Altura:215
#
# Peso:70
# Peso:60
# Altura:220
#
# Peso:71
# Peso:59
# Altura:225
#
# Peso:72
# Peso:58
# Altura:230
#
# Peso:73
# Peso:57
# Altura:235
#
# Peso:74
# Peso:56
# Altura:240
#
# Peso:75
# Peso:55
# Altura:245
#
# Peso:76
# Peso:54
# Altura:250
#
# Peso:77
# Peso:53
# Altura:255
#
# Peso:78
# Peso:52
# Altura:260
#
# Peso:79
# Peso:51
# Altura:265
#
# Peso:80
# Peso:50
# Altura:270
