# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
texto1 = input("digite um texto ")
texto2 = input("digite um texto ")
print(f"Tamanho de {texto1}: {len(texto1)} caracteres")
print(f'Tamanho de "{texto2}": {len(texto2)} caracteres')
if len(texto1) == len(texto2):
    if texto1 == texto2:
        print("As duas strings possuem contéudo iguais")
        print("As duas string são de tamanhos iguais")
    else:
        print("As duas string são de tamanhos iguais")
        print("As duas string possuem conteúdos diferentes")
else:
        print("As duas string são de tamanhos diferentes")
        print("As duas string possuem conteúdos diferentes")
# Out:
# digite um texto vitor
# digite um texto votir
# Tamanho de vitor: 5 caracteres
# Tamanho de "votir": 5 caracteres
# As duas string são de tamanhos iguais
# As duas string possuem conteúdos diferentes

# %% [markdown]
# Nome ao contrário em maiúsculas. Faça um programa que permita ao usuário digitar o seu nome e em seguida mostre o nome do usuário de trás para frente utilizando somente letras maiúsculas. Dica: lembre−se que ao informar o nome o usuário pode digitar letras maiúsculas ou minúsculas.

# %%
# Out:
# Digite seu nome vitor
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-48-5cc5a07219e9> in <module>()
#       2 texto = input("Digite seu nome ").upper()
#       3 for i in range(len(texto) - 1, -1, -1):
# ----> 4     texto1[i] = texto[i]
#       5     print(i)
#
# IndexError: list assignment index out of range

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
texto = input("digite seu nome")
for i in range(len(texto)):
    print(texto[i])
# Out:
# digite seu nomevitor
# v
# i
# t
# o
# r

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
texto = input("digite seu nome ")
texto2 = ""
for i in range(len(texto)):
    texto2 += texto[i] 
    print(texto2)
# Out:
# digite seu nome vitor
# v
# vi
# vit
# vito
# vitor

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
nome = input('Informe seu nome: ')
for i in range(len(nome) - 1, -1, -1):
    for j in range(0, i + 1):
        print (nome[j], end="")
    print("")
# Out:
# Informe seu nome: vitor
# vitor
# vito
# vit
# vi
# v

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import re


def validaData(dia, mes, ano):
    # Valida o dia
    if (dia < 0) or (dia > 31):
        return False

    # Valida mes com 30 dias
    meses30 = (4, 6, 9, 11)
    if (mes in meses30):
        if (dia > 30):
            return False

    # Valida fevereiro e anos bissextos
    if (mes == 2):
        if (dia > 28):
            if (ano % 4 != 0):
                return False
            elif (ano % 100 == 0) and (ano % 1000 != 0):
                return False

    return True


def dataPorExtenso(data):
    # Valida o formato da data por expressao regular
    reg = re.compile('^[0-9]{2}\/[0-9]{2}\/[0-9]{4}$')
    if (not (reg.match(data))):
        print ('Data invalida')
        return None

    dia = int(data[:2])
    mes = int(data[3:5])
    ano = int(data[6:])

    if (not validaData(dia, mes, ano)):
        return ("Voce digitou algo errado")

    mesExtenso = ('Janeiro', 'Fevereiro', 'Marco', 'Abril', 'Maio', 'Junho',
                  'Julho', 'Agosto', 'Setembro', 'Outubro', 'Novembro',
                  'Dezembro')

    return '%d de %s de %d' % (dia, mesExtenso[mes - 1], ano)

# Fluxo Principal

data = input('Informe uma data no formato dd/mm/yyyy: ')
print (dataPorExtenso(data))
# Out:
# Informe uma data no formato dd/mm/yyyy: 31/11/2020
# Voce digitou algo errado

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
texto = input("Digite um texto ").upper()
vogal = espaco_branco = 0
for i in range (len(texto)):
    if texto[i] == " ":    
        espaco_branco += 1
    if texto[i] == "A" or texto[i] == "E" or texto[i] == "I" or texto[i] == "O" or texto[i] == "U":
        vogal += 1
print("O numero de espaços em branco foi {0} e o numero de vogal foi {1}".format(espaco_branco,vogal))
# Out:
# Digite um texto vitor hugo
# O numero de espaços em branco foi 1 e o numero de vogal foi 4

# %% [markdown]
# Palíndromo. Um palíndromo é uma seqüência de caracteres cuja leitura é idêntica se feita da direita para esquerda ou vice−versa. Por exemplo: OSSO e OVO são palíndromos. Em textos mais complexos os espaços e pontuação são ignorados. A frase SUBI NO ONIBUS é o exemplo de uma frase palíndroma onde os espaços foram ignorados. Faça um programa que leia uma seqüência de caracteres, mostre−a e diga se é um palíndromo ou não.

# %%
string = input('Informe uma string: ').upper()
contrario = string[::-1]

if (string.replace(' ', '') == contrario.replace(' ', '')):
    print ('A string eh um palindromo')
else:
    print ('A string NAO eh um palindromo')
# Out:
# Informe uma string: vitor
# A string NAO eh um palindromo

# %% [markdown]
# Verificação de CPF. Desenvolva um programa que solicite a digitação de um número de CPF no formato xxx.xxx.xxx-xx e indique se é um número válido ou inválido através da validação dos dígitos verificadores edos caracteres de formatação.

# %%
def validaCPF(cpf):

    cpf = cpf.replace('.', '')
    cpf = cpf.replace('-', '')
    if (len(cpf) != 11):
        return False

    # Realiza a multiplicacao dos 9 primeiros numeros
    fator = 10
    soma = 0
    for i in range(0, 9):
        soma += (int(cpf[i]) * fator)
        fator -= 1

    # Divide o somatorio por 11 e pega o resto
    resto = soma % 11

    # Se o resto eh menor que 2, entao o primeiro digito verificador eh 0,
    #  senao diminui o resto do valor 11
    if (resto < 2):
        digito1 = 0
    else:
        digito1 = 11 - resto

    # Agora verifica o segundo digito com os 10 primeiros numeros
    fator = 11
    soma = 0
    for i in range(0, 10):
        soma += (int(cpf[i]) * fator)
        fator -= 1

    # Divide o somatorio por 11 e pega o resto
    resto = soma % 11

    # Se o resto eh menor que 2, entao o segundo digito verificador eh 0,
    #  senao diminui o resto do valor 11
    if (resto < 2):
        digito2 = 0
    else:
        digito2 = 11 - resto

    if (int(cpf[9]) == digito1) and (int(cpf[10]) == digito2):
        return True

    return False

###
# FLUXO PRINCIPAL

cpf = input('Informe o CPF: ')
if (validaCPF(cpf)):
    print ('CPF valido')
else:
    print ('CPF INVALIDO')
# Out:
# Informe o CPF: 44038568595
# CPF INVALIDO

# %% [markdown]
# Número por extenso. Escreva um programa que solicite ao usuário a digitação de um número até 99 e imprima-o na tela por extenso.

# %%
dezenas = ['', '', 'vinte', 'trinta', 'quarenta',
           'cinquenta', 'sessenta', 'setenta', 'oitenta', 'noventa']
primeira_dezena = ['dez', 'onze', 'doze', 'treze', 'catorze',
                   'quinze', 'dezesseis', 'dezessete', 'dezoito', 'dezenove']
unidades = ['zero', 'um', 'dois', 'tres', 'quatro',
            'cinco', 'seis', 'sete', 'oito', 'nove']

numero = int(input('Informe um numero: '))
if (numero < 0) or (numero > 99):
    print ('O numero informado deve estar entre 0 e 99')
else:
    dezena = numero / 10
    unidade = numero % 10

    if (numero >= 20):
        print ('{0}' .format(dezenas[int(dezena)]),end="")
        if (unidade != 0):
            print ('e {0}' .format(unidades[unidade]))
    elif (numero >= 10):
        print ('{0}' .format(primeira_dezena[unidade]))
    else:
        print ('{0}'.format(unidades[unidade]))
# Out:
# Informe um numero: 5
# cinco

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import random

# Abre o arquivo para leitura
arquivoEntrada = open('11_palavras.txt', 'r')

# Coloca todas as linhas em memoria
palavras = arquivoEntrada.readlines()

# Fecha o arquivo
arquivoEntrada.close()

palavraEscolhida = palavras[
    random.randint(0, len(palavras) - 1)].upper().strip()
tamanhoPalavra = len(palavraEscolhida)
palavraAdivinhada = ['_'] * tamanhoPalavra

numTentativas = 0
numErros = 0

while (''.join(palavraAdivinhada) != palavraEscolhida) and (numErros < 6):

    letra = input('Digite uma letra: ').upper()
    numTentativas += 1
    acertou = False

    print ('A palavra eh: ', end="")
    for i in range(0, tamanhoPalavra):
        if (palavraEscolhida[i] == letra):
            palavraAdivinhada[i] = letra
            acertou = True
        print ('{0}'.format(palavraAdivinhada[i]),end="")

    if (not acertou):
        numErros += 1
        print ('Voce errou pela {0}da. vez.'.format(numErros)

if (numErros < 6):
    print ('Voce acertou!')
else:
    print ('Voce perdeu!')
    print ('A palavra era {0}'.format(palavraEscolhida))

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
print ('Valida e corrige numero de telefone')
telefone = input('Telefone: ')

telefoneLimpo = telefone.replace('-', '')

if (len(telefoneLimpo) == 7):
    print ('Telefone possui 7 digitos. Vou acrescentar o digito tres na frente.')
    print ('Telefone corrigido sem formatacao: {0}'.format(telefoneLimpo))
    print ('Telefone corrigido com formatacao: {0}'.format(telefone))

# %% [markdown]
# Jogo da palavra embaralhada. Desenvolva um jogo em que o usuário tenha que adivinhar uma palavra que será mostrada com as letras embaralhadas. O programa terá uma lista de palavras lidas de um arquivo texto e escolherá uma aleatoriamente. O jogador terá seis tentativas para adivinhar a palavra. Ao final a palavra deve ser mostrada na tela, informando se o usuário ganhou ou perdeu o jogo.

# %%
import random

# Abre o arquivo para leitura
arquivoEntrada = open('11_palavras.txt', 'r')

# Coloca todas as linhas em memoria
palavras = arquivoEntrada.readlines()

# Fecha o arquivo
arquivoEntrada.close()

palavraEscolhida = palavras[
    random.randint(0, len(palavras) - 1)].upper().strip()
tamanhoPalavra = len(palavraEscolhida)
palavraAdivinhada = random.sample(palavraEscolhida, len(palavraEscolhida))
for i in palavraAdivinhada:
    print ('{0}'.format(i), end="")
print

palavra = input('Digite qual eh a palavra: ').upper()

if (palavra == palavraEscolhida):
    print ('Voce acertou!')
else:
    print ('Voce perdeu!'))
    print ('A palavra era {0}'.format(palavraEscolhida))

# %% [markdown]
# Leet spek generator. Leet é uma forma de se escrever o alfabeto latino usando outros símbolos em lugar das letras, como números por exemplo. A própria palavra leet admite muitas variações, como l33t ou 1337. O uso do leet reflete uma subcultura relacionada ao mundo dos jogos de computador e internet, sendo muito usada para confundir os iniciantes e afirmar-se como parte de um grupo. Pesquise sobre as principais formas de traduzir as letras. Depois, faça um programa que peça uma texto e transforme-o para a grafia leet speak.

# %%
leet = {
    'A': '4',
    'B': '8',
    'C': '<',
    'D': '[)',
    'E': '&',
    'F': 'ph',
    'G': '6',
    'H': '#',
    'I': '1',
    'J': 'j',
    'K': '|<',
    'L': '|_',
    'M': '|\/|',
    'N': '/\/',
    'O': '0',
    'P': '|*',
    'Q': '9',
    'R': 'l2',
    'S': '5',
    'T': '7',
    'U': 'v',
    'V': 'V',
    'W': 'vv',
    'X': '><',
    'Y': '`/',
    'Z': '2'
}

texto = input('Informe um texto: ')
print ('Texto em Leet Spek:')

for i in texto.upper():
    if i.isalpha():
        print (leet[i],end="")
    else:
        print (' ',end="")
# Out:
# Informe um texto: votir
# Texto em Leet Spek:
# V071l2
